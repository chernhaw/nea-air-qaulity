# %% [markdown]
# # Did PSI drop during Covid?

# %%
import pandas as pd
import json
import os

current_dir = os.getcwd()
print("Current directory:", current_dir)
# Out:
# Current directory: /Users/tongchernhaw/Desktop/NEA Air

# %% [markdown]
# ## Load psi for 2020

# %%
df_psi_2020= pd.read_csv("HistoricalPollutantStandardsIndexPSI2020.csv")

df_psi_2020.head()
# Out:
#          date                  timestamp           update_timestamp   region  \
# 0  2020-01-01  2020-01-01T00:00:00+08:00  2020-01-01T00:08:52+08:00    south
# 1  2020-01-01  2020-01-01T00:00:00+08:00  2020-01-01T00:08:52+08:00    north
# 2  2020-01-01  2020-01-01T00:00:00+08:00  2020-01-01T00:08:52+08:00     east
# 3  2020-01-01  2020-01-01T00:00:00+08:00  2020-01-01T00:08:52+08:00  central
# 4  2020-01-01  2020-01-01T00:00:00+08:00  2020-01-01T00:08:52+08:00     west
#
#   region_id  location_longitude  location_latitude  pm10_twenty_four_hourly  \
# 0       rSO              103.82            1.29587                     22.0
# 1       rNO              103.82            1.41803                     18.0
# 2       rEA              103.94            1.35735                     22.0
# 3       rCE              103.82            1.35735                     18.0
# 4       rWE              103.70            1.35735                     21.0
#
# ...

# %%
df_psi_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50778 entries, 0 to 50777
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     50778 non-null  object
#  1   timestamp                50778 non-null  object
#  2   update_timestamp         50778 non-null  object
#  3   region                   50778 non-null  object
#  4   region_id                50778 non-null  object
#  5   location_longitude       50778 non-null  float64
#  6   location_latitude        50778 non-null  float64
#  7   pm10_twenty_four_hourly  50778 non-null  float64
#  8   pm10_sub_index           50778 non-null  float64
#  9   pm25_twenty_four_hourly  50778 non-null  float64
#  10  pm25_sub_index           50778 non-null  float64
#  11  o3_eight_hour_max        50778 non-null  float64
#  12  o3_sub_index             50698 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2020['date']), df_psi_2020['pm10_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('PM10 Sub Index')
plt.title('PM10 Sub Index over Time (2020)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2020['date']), df_psi_2020['pm25_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('PM10 Sub Index')
plt.title('PM10 Sub Index over Time (2020)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2020['date']), df_psi_2020['so2_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('SO2 Sub Index')
plt.title('SO2 Sub Index over Time (2020)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2020['date']), df_psi_2020['o3_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('O3 Sub Index')
plt.title('O3 Sub Index over Time (2020)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_psi_2021= pd.read_csv("HistoricalPollutantStandardsIndexPSI2021.csv")

df_psi_2021.head()
# Out:
#          date                  timestamp           update_timestamp   region  \
# 0  2021-01-01  2021-01-01T00:00:00+08:00  2021-01-01T00:08:52+08:00    south
# 1  2021-01-01  2021-01-01T00:00:00+08:00  2021-01-01T00:08:52+08:00    north
# 2  2021-01-01  2021-01-01T00:00:00+08:00  2021-01-01T00:08:52+08:00     east
# 3  2021-01-01  2021-01-01T00:00:00+08:00  2021-01-01T00:08:52+08:00  central
# 4  2021-01-01  2021-01-01T00:00:00+08:00  2021-01-01T00:08:52+08:00     west
#
#   region_id  location_longitude  location_latitude  pm10_twenty_four_hourly  \
# 0       rSO              103.82            1.29587                     31.0
# 1       rNO              103.82            1.41803                     28.0
# 2       rEA              103.94            1.35735                     36.0
# 3       rCE              103.82            1.35735                     29.0
# 4       rWE              103.70            1.35735                     25.0
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2021['date']), df_psi_2021['pm10_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('PM10 Sub Index')
plt.title('PM10 Sub Index over Time (2021)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_psi_2019= pd.read_csv("HistoricalPollutantStandardsIndexPSI2019.csv")

df_psi_2019.head()
# Out:
#          date                  timestamp           update_timestamp   region  \
# 0  2019-01-01  2019-01-01T00:00:00+08:00  2019-01-01T00:03:52+08:00    south
# 1  2019-01-01  2019-01-01T00:00:00+08:00  2019-01-01T00:03:52+08:00    north
# 2  2019-01-01  2019-01-01T00:00:00+08:00  2019-01-01T00:03:52+08:00     east
# 3  2019-01-01  2019-01-01T00:00:00+08:00  2019-01-01T00:03:52+08:00  central
# 4  2019-01-01  2019-01-01T00:00:00+08:00  2019-01-01T00:03:52+08:00     west
#
#   region_id  location_longitude  location_latitude  pm10_twenty_four_hourly  \
# 0       rSO              103.82            1.29587                     18.0
# 1       rNO              103.82            1.41803                     17.0
# 2       rEA              103.94            1.35735                     23.0
# 3       rCE              103.82            1.35735                     15.0
# 4       rWE              103.70            1.35735                     16.0
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2019['date']), df_psi_2019['pm10_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('PM10 Sub Index')
plt.title('PM10 Sub Index over Time (2019)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2019['date']), df_psi_2019['pm25_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('PM25 Sub Index')
plt.title('PM25 Sub Index over Time (2019)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df_psi_2019['date']), df_psi_2019['o3_sub_index'], label='PM10 Sub Index')
plt.xlabel('Date')
plt.ylabel('O3 Sub Index')
plt.title('O3 Sub Index over Time (2019)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([
    df_psi_2019['o3_sub_index'].dropna(),
    df_psi_2020['o3_sub_index'].dropna(),
    df_psi_2021['o3_sub_index'].dropna()
], labels=['2019', '2020', '2021'])
plt.ylabel('O3 Sub Index')
plt.title('Box Plot of O3 Sub Index for 2019, 2020, and 2021')
plt.show()
# Out:
# /var/folders/w2/svppx15n0q1f6269nrsbflrr0000gn/T/ipykernel_2135/900697985.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([
    df_psi_2019['pm25_sub_index'].dropna(),
    df_psi_2020['pm25_sub_index'].dropna(),
    df_psi_2021['pm25_sub_index'].dropna()
], labels=['2019', '2020', '2021'])
plt.ylabel('CO Sub Index')
plt.title('Box Plot of PM25 Sub Index for 2019, 2020, and 2021')
plt.show()
# Out:
# /var/folders/w2/svppx15n0q1f6269nrsbflrr0000gn/T/ipykernel_2135/3538638832.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([
    df_psi_2019['pm10_sub_index'].dropna(),
    df_psi_2020['pm10_sub_index'].dropna(),
    df_psi_2021['pm10_sub_index'].dropna()
], labels=['2019', '2020', '2021'])
plt.ylabel('PM10 Sub Index')
plt.title('Box Plot of PM10 Sub Index for 2019, 2020, and 2021')
plt.show()
# Out:
# /var/folders/w2/svppx15n0q1f6269nrsbflrr0000gn/T/ipykernel_2135/921232929.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([

   # df_psi_2020['so2_sub_index'].dropna()
    df_psi_2019['so2_sub_index'].dropna(),
    df_psi_2020['so2_sub_index'].dropna(),
    df_psi_2021['so2_sub_index'].dropna()
], labels=['2019', '2020', '2021'])
plt.ylabel('SO2 Sub Index')
plt.title('Box Plot of SO2 Sub Index for 2019, 2020, and 2021')
plt.show()
# Out:
# /var/folders/w2/svppx15n0q1f6269nrsbflrr0000gn/T/ipykernel_2135/779371708.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([

# %% [markdown]
# ## SO2 observed to have dropped slightly, road vehicle down?
